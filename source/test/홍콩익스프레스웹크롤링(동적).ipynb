# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from datetime import date

driver = webdriver.Chrome()
driver.get("https://www.hkexpress.com/en-HK/Legal-and-Privacy/Conditions-of-Carriage-for-Passengers-and-Baggage")
time.sleep(4)
