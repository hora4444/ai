# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% ! important;}
div.cell.code_cell.rendered{width:100%}
div.input_prompt{padding:0px}
div.CodeMirror {font-family:Consolas ; font-size:12pt;}
div.text_cell_render.rendered_html {font-size:12pt;}
div.output {font-size:12pt; font-weight:bold}
div.input {font-family:Consolas ; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% ! important;}
# div.cell.code_cell.rendered{width:100%}
# div.input_prompt{padding:0px}
# div.CodeMirror {font-family:Consolas ; font-size:12pt;}
# div.text_cell_render.rendered_html {font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold}
# div.input {font-family:Consolas ; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <b><font size="6" color="red">ch.09 시계열데이터 분석 및 예측</font></b>
# - pip install statsmodels==0.13.5 		# 주기적인 데이터의 트렌드 추이
# - pip install prophet 			# facebook에서 개발한 시계열 예측 lib

# %%
# %pip install statsmodels==0.13.5
# Out:
# Collecting statsmodels==0.13.5
#   Downloading statsmodels-0.13.5-cp310-cp310-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: pandas>=0.25 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels==0.13.5) (1.5.3)
# Collecting patsy>=0.5.2 (from statsmodels==0.13.5)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels==0.13.5) (25.0)
# Requirement already satisfied: scipy>=1.3 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels==0.13.5) (1.15.3)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels==0.13.5) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from pandas>=0.25->statsmodels==0.13.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from pandas>=0.25->statsmodels==0.13.5) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->statsmodels==0.13.5) (1.17.0)
# Downloading statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ------------------------------------- -- 8.7/9.1 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 56.6 MB/s  0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.2 statsmodels-0.13.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.2.1-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (1.5.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.86-py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (4.67.1)
# Collecting importlib_resources (from prophet)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: python-dateutil in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Downloading prophet-1.2.1-py3-none-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ----------------------------------- ---- 10.7/12.1 MB 61.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 50.6 MB/s  0:00:00
# Downloading holidays-0.86-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 71.0 MB/s  0:00:00
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: stanio, importlib_resources, holidays, cmdstanpy, prophet
#
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    ---------------- ----------------------- 2/5 [holidays]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    -------------------------------- ------- 4/5 [prophet]
#    ---------------------------------------- 5/5 [prophet]
#
# Successfully installed cmdstanpy-1.3.0 holidays-0.86 importlib_resources-6.5.2 prophet-1.2.1 stanio-0.5.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts install_cmdstan.exe and install_cxx_toolchain.exe are installed in 'C:\Users\Admin\anaconda3\envs\ml-dl-nlp\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 한글설정
plt.rc('font', family = 'Malgun Gothic') # 원도우즈서 시각화시 한글 깨짐 방지
plt.rc('axes', unicode_minus=False) # 축의 '-' 깨짐 방지

# %%
# AirKoread 사이트에 다운로드
df = pd.read_csv('data/일별평균대기오염도_2022(에어코리아).csv', encoding='cp949')
df.head()
# Out:
#        측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20220101   강남구         0.029      0.014           0.5         0.003
# 1  20220101   홍릉로         0.038      0.009           0.6         0.004
# 2  20220101    행주         0.034      0.012           0.7         0.004
# 3  20220101    항동         0.030      0.011           0.5         0.003
# 4  20220101  한강대로         0.037      0.011           0.6         0.003
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         25.0          12.0
# 1         27.0          16.0
# 2         27.0          16.0
# 3         27.0          14.0
# 4         34.0          14.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  int64
#  1   측정소명          18250 non-null  object
#  2   이산화질소농도(ppm)  18172 non-null  float64
#  3   오존농도(ppm)     18176 non-null  float64
#  4   일산화탄소농도(ppm)  18174 non-null  float64
#  5   아황산가스농도(ppm)  18176 non-null  float64
#  6   미세먼지농도(㎍/㎥)   18115 non-null  float64
#  7   초미세먼지농도(㎍/㎥)  18122 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
# 미세먼지농도(㎍/㎥)가 결측치인 데이터
df[df['미세먼지농도(㎍/㎥)'].isna()]
# 결측치가 한 열이라도 있는 행
df.isna().any(axis=1)
# 결측치가 한 열이라도 있는 행의 측정소명
# df[df.isna().any(axis=1)]['측정소명'].unique()
df.loc[df.isna().any(axis=1), '측정소명'].unique()
# Out:
# array(['남산', '세곡', '관악산', '마포아트센터', '서대문구', '도산대로', '북한산', '항동', '동작구',
#        '서초구', '동작대로', '행주', '올림픽공원', '동대문구', '송파구', '은평구', '한강대로', '강변북로',
#        '시흥대로', '성북구', '관악구'], dtype=object)

# %%
plt.figure(figsize=(22,5))
plt.plot(df['측정일시'], df['미세먼지농도(㎍/㎥)'])

# %%
# 측정일시 컬럼을 날짜형으로 변환
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  int64
#  1   측정소명          18250 non-null  object
#  2   이산화질소농도(ppm)  18172 non-null  float64
#  3   오존농도(ppm)     18176 non-null  float64
#  4   일산화탄소농도(ppm)  18174 non-null  float64
#  5   아황산가스농도(ppm)  18176 non-null  float64
#  6   미세먼지농도(㎍/㎥)   18115 non-null  float64
#  7   초미세먼지농도(㎍/㎥)  18122 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df['측정일'] = df['측정일시'].astype(str)
df.dtypes
# Out:
# 측정일시              int64
# 측정소명             object
# 이산화질소농도(ppm)    float64
# 오존농도(ppm)       float64
# 일산화탄소농도(ppm)    float64
# 아황산가스농도(ppm)    float64
# 미세먼지농도(㎍/㎥)     float64
# 초미세먼지농도(㎍/㎥)    float64
# 측정일              object
# dtype: object

# %%
df.head()
# Out:
#        측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20220101   강남구         0.029      0.014           0.5         0.003
# 1  20220101   홍릉로         0.038      0.009           0.6         0.004
# 2  20220101    행주         0.034      0.012           0.7         0.004
# 3  20220101    항동         0.030      0.011           0.5         0.003
# 4  20220101  한강대로         0.037      0.011           0.6         0.003
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)       측정일
# 0         25.0          12.0  20220101
# 1         27.0          16.0  20220101
# 2         27.0          16.0  20220101
# 3         27.0          14.0  20220101
# 4         34.0          14.0  20220101

# %%
df['측정일'] = df['측정일'].str[:4] + '-' + df['측정일'].str[4:6] + '-' + df['측정일'].str[6:]

# %%
df[['측정일시', '측정일']].sample()
# Out:
#            측정일시         측정일
# 0      20220101  2022-01-01
# 1      20220101  2022-01-01
# 2      20220101  2022-01-01
# 3      20220101  2022-01-01
# 4      20220101  2022-01-01
# ...         ...         ...
# 18245  20221231  2022-12-31
# 18246  20221231  2022-12-31
# 18247  20221231  2022-12-31
# 18248  20221231  2022-12-31
# 18249  20221231  2022-12-31
#
# [18250 rows x 2 columns]

# %%
df['측정일'] = pd.to_datetime(df['측정일'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  int64
#  1   측정소명          18250 non-null  object
#  2   이산화질소농도(ppm)  18172 non-null  float64
#  3   오존농도(ppm)     18176 non-null  float64
#  4   일산화탄소농도(ppm)  18174 non-null  float64
#  5   아황산가스농도(ppm)  18176 non-null  float64
#  6   미세먼지농도(㎍/㎥)   18115 non-null  float64
#  7   초미세먼지농도(㎍/㎥)  18122 non-null  float64
#  8   측정일           18250 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
# df의 열순서를 변경
cols = df.columns.tolist()
cols = [cols[0], cols[-1]] + cols[1:-1]
df = df[cols]
df.head()
# Out:
#        측정일시        측정일  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  \
# 0  20220101 2022-01-01   강남구         0.029      0.014           0.5
# 1  20220101 2022-01-01   홍릉로         0.038      0.009           0.6
# 2  20220101 2022-01-01    행주         0.034      0.012           0.7
# 3  20220101 2022-01-01    항동         0.030      0.011           0.5
# 4  20220101 2022-01-01  한강대로         0.037      0.011           0.6
#
#    아황산가스농도(ppm)  미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         0.003         25.0          12.0
# 1         0.004         27.0          16.0
# 2         0.004         27.0          16.0
# 3         0.003         27.0          14.0
# 4         0.003         34.0          14.0

# %%
df.drop('측정일시', axis=1, inplace=True)
df.sample()
# Out:
#             측정일 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 1425 2022-01-29  성북구         0.019      0.027           0.4         0.003
#
#       미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 1425         24.0          12.0

# %%
df.columns = ['측정일', '측정소명', '이산화질소농도', '오존농도', '일산화탄소농도', '아황산가스농도', '미세먼지농도', '초미세먼지농도']

# %%
df.columns
# Out:
# Index(['측정일', '측정소명', '이산화질소농도', '오존농도', '일산화탄소농도', '아황산가스농도', '미세먼지농도',
#        '초미세먼지농도'],
#       dtype='object')

# %%
# 결측치가 없는 측정소명만 추출
df_flt = df[df['측정소명'] == '공항대로']

# %%
# 미세먼지농도, 초미세먼지농도 시계열 데이터 시각화
plt.figure(figsize=(25,5))
plt.plot(df_flt['측정일'], df_flt['미세먼지농도'], label='미세먼지농도')
plt.plot(df_flt['측정일'], df_flt['초미세먼지농도'], label='초미세먼지농도')
plt.xlabel('측정일')
plt.ylabel('먼지농도(㎍/㎥)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### statsmodels
# - 주기적인 데이터의 트렌드 추이(결측치 없는 데이터만 사용 가능)
# - 날짜형 인덱스와 데이터 컬럼

# %%
df_flt2 = df_flt[['측정일', '미세먼지농도']]
ts = df_fit2.set_index('측정일')
ts.head()
# Out:
#             미세먼지농도
# 측정일
# 2022-01-01    31.0
# 2022-01-02    37.0
# 2022-01-03    31.0
# 2022-01-04    48.0
# 2022-01-05    56.0

# %%
# 시계열 데이터의 구조를 분해하는 도구 : 실제값 추세, 계절성, 잔차를 분석
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(ts['미세먼지농도'], period=30) # 30일 단위로 계절성을 분석

# %%
# result.observed # 실제 데이터
# result.trend # 데이터의 장기적인 변화, 전반적으로 감소, 증가
# result.seasonal # 주기적인 계절성 패턴
# result.resid # 잔차(실제값에서 추세와 계절성을 뺀 노이즈)
flg, axes = plt.subplots(4,1, figsize=(20,8))
# axes[0].plot(result.observed)
result.observed.plot(ax=axes[0])
result.trend.plot(ax=axes[1]) 
result.seasonal.plot(ax=axes[2])
result.resid.plot(ax=axes[3])
plt.show()

# %% [markdown]
# ### Prophet
# - 계절성, 추세, 휴일 효과 등을 자동으로 모델, 예측
# - ds(시간), y(시계열성 숫자) 컬럼

# %%
df_flt2.columns=['ds', 'y'] # fit시 컬럼명 ds,y를 읽음
df_flt2.head(1)
# Out:
#            ds     y
# 44 2022-01-01  31.0

# %%
from prophet import Prophet
# 1. 모델 생성
p_model = Prophet()
# 2. 학습
p_model.fit(df_flt2)
# Out:
# 17:49:07 - cmdstanpy - INFO - Chain [1] start processing
# 17:49:08 - cmdstanpy - INFO - Chain [1] done processing

# %%
# 3. 30일 이후의 데이터를 예측하는 미래 df을 생성
future = p_model.make_future_dataframe(periods=30)
# 4. 예측수행
forecast = p_model.predict(future)
# forecast.tail(30)
# 5. 시각화
p = p_model.plot(forecast)

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(30)
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 365 2023-01-01  38.738264   15.871608   59.397715
# 366 2023-01-02  39.108784   17.155002   60.391711
# 367 2023-01-03  43.966999   21.695978   64.708170
# 368 2023-01-04  45.272272   21.971524   69.233035
# 369 2023-01-05  42.812966   21.034512   65.215483
# 370 2023-01-06  44.613397   21.618988   67.321728
# 371 2023-01-07  44.275891   23.595851   66.390245
# 372 2023-01-08  39.550926   17.152830   62.154524
# 373 2023-01-09  39.921445   18.012056   62.503616
# 374 2023-01-10  44.779660   23.288559   67.553069
# 375 2023-01-11  46.084933   24.381065   68.242668
# 376 2023-01-12  43.625628   22.733211   68.236584
# 377 2023-01-13  45.426059   23.045017   65.872278
# 378 2023-01-14  45.088552   24.712457   66.831513
# 379 2023-01-15  40.363587   18.171836   61.990316
# 380 2023-01-16  40.734107   20.063708   61.568384
# 381 2023-01-17  45.592322   23.054261   68.063673
# 382 2023-01-18  46.897595   24.361829   69.126279
# 383 2023-01-19  44.438289   22.985119   67.523625
# 384 2023-01-20  46.238720   24.760644   69.075649
# 385 2023-01-21  45.901214   22.001672   70.375209
# 386 2023-01-22  41.176249   19.486597   63.171523
# 387 2023-01-23  41.546768   19.379218   64.181785
# 388 2023-01-24  46.404983   25.077861   68.928859
# 389 2023-01-25  47.710256   24.104803   68.433089
# 390 2023-01-26  45.250951   22.052984   68.555090
# 391 2023-01-27  47.051382   23.987465   67.933308
# 392 2023-01-28  46.713875   24.879798   70.522460
# 393 2023-01-29  41.988910   20.904631   64.303574
# 394 2023-01-30  42.359430   20.641189   64.728396

# %%
# 트랜드와 휴일 효과
p = p_model.plot_components(forecast)

# %%
# 2023-01-12
forecast.loc[forecast['ds']=='2023-01-06',['ds', 'yhat']]
# Out:
#             ds       yhat
# 370 2023-01-06  44.613397
