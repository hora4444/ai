# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% ! important;}
div.cell.code_cell.rendered{width:100%}
div.input_prompt{padding:0px}
div.CodeMirror {font-family:Consolas ; font-size:12pt;}
div.text_cell_render.rendered_html {font-size:12pt;}
div.output {font-size:12pt; font-weight:bold}
div.input {font-family:Consolas ; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper {padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% ! important;}
# div.cell.code_cell.rendered{width:100%}
# div.input_prompt{padding:0px}
# div.CodeMirror {font-family:Consolas ; font-size:12pt;}
# div.text_cell_render.rendered_html {font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold}
# div.input {font-family:Consolas ; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper {padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # 1.환경변수

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# - ollama.com에서 모델 선택(llama / exaone)
#     * powershell이나 cmd창에서 ollama pull llama3.2:1b
#     * powershell이나 cmd창에서 ollama pull exaone3.5:2.4b

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatOllama(
    model='exaone3.5:2.4b',
)
messages = [
    SystemMessage(content = "너는 친절하게 대답해 주는 비서야"),
    HumanMessage(content="2020년 월드 시리즈 누가 우승했어?")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 MLB 월드 시리즈에서 우승한 팀은 **휴스턴 애스트로스**입니다! \n\n그들은 뉴욕 양키스를 꺾고 리그 챔피언십 우승을 차지했죠. 🎉🏆', additional_kwargs={}, response_metadata={'model': 'exaone3.5:2.4b', 'created_at': '2026-01-07T05:33:01.1239159Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4764475000, 'load_duration': 1712831600, 'prompt_eval_count': 42, 'prompt_eval_duration': 951840500, 'eval_count': 47, 'eval_duration': 2000579100, 'logprobs': None, 'model_name': 'exaone3.5:2.4b', 'model_provider': 'ollama'}, id='lc_run--019b96f1-a0a3-71a2-8750-85046a322dfc-0', usage_metadata={'input_tokens': 42, 'output_tokens': 47, 'total_tokens': 89})

# %%
ai_message.content
# Out:
# '2020년 MLB 월드 시리즈에서 우승한 팀은 **휴스턴 애스트로스**입니다! \n\n그들은 뉴욕 양키스를 꺾고 리그 챔피언십 우승을 차지했죠. 🎉🏆'
